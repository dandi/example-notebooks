# %% [markdown]
# # README
#
# From the same working directory as this notebook, first setup the environment by calling:
#
# ```bash
# conda env create --file 001075_notebook_environment.yaml
# conda activate 001075_notebook_environment
# ```
#
# then launch this notebook from `jupyter notebook`.

# %%
# Import the local module containing helper functions specific to Dandiset 001075
import utils_001075

# %%
subject_id = "26"
session_id = "20211104-163944"

# %%
segmentation_nwbfile = utils_001075.stream_nwbfile(subject_id=subject_id, session_id=session_id, session_type="segmentation")

# %%
utils_001075.plot_waterfall(segmentation_nwbfile=segmentation_nwbfile)
